# %% [markdown]
#                                                    Theory Questions

# %% [markdown]
# Q1.  What are the different types of errors that can occur in a Python Program and how are they classified ?

# %% [markdown]
# Ans.
# In Python, errors can be broadly classified into three types of syntax erros, runtime erros and logical errors.  Syntax erros occur when
# the Python Interpreter encounters the incorrect syntax in the code. , preventing it from passing  and executing the program.
#
# Runtime errors are also known as exceptions occur during the execution of the program when something unexpected happens such as division by zero or trying to access a non existent file.
#
# Logical errors on the other hand accur when the program runs without any syntax or runtime errors but produces incorrect results due to
# flawed logic.

# %% [markdown]
# Q2. Explain the concept of exceptions in Python Programming ?  How are exceptions raised and handled ?

# %% [markdown]
# Ans.
# Exceptions in Python are the events that occur during the execution of a program that disrupt the normal flow of instructions.
#
# They can be raised explicitly by Python Interpreter when an error condition is encontured.  Exceptions are handled during thr try except block where the code that may raise an exeption is placed inside the try block and handling the code is placed inside the except block, ehere the code that might raise an exception is placed inside the try block, and handling code is placed inside the excepet block.

# %% [markdown]
# Q3. Describe the significance of syntax errors in Python. How does the interpreter handle syntax error ?

# %% [markdown]
# Ans.
# Syntax errors in Python occur when the interpreter encounters the code that violates the language syntax rules that are there.
#
# These rules prevent the interpreter from passing the code and generating the bytecode for execution. When a syntax error is encountered, the Syntax error exception occurs and provides information about the location and the nature of the code syntax, allowing the developers to correct it before running the program.

# %% [markdown]
# Q4. Dicuss the role of in built exceptions in Python. Provide examples of commonly occuring built in exceptions and their explanations.

# %% [markdown]
# Ans.
#
# Built in exceptions in Python are pre defined classes that represent the various error conditions that can occur during the programexecution. Examples of coomonly occuring built in exceptions include Value Error.
#
# Value Error is raised when an operation or function receives an argument of the correcct type but with an inappropraite value.
#
# Type Error : Its raise when an operation or the function is applied to the object of inappropriate type.
#
# File Not Found Error occurs when the file which we are trying to open or manipulate, does not exist.

# %% [markdown]
# Q5
# Describe the process of opening and cloing a text file in Python, including the syntax and optional arguments

# %% [markdown]
# Ans.
# Exceptions can be forcefully raised in Python using the raise statement.  By explicitly raising the exceptions, developers can
# signal abnormal conditions in their code and handle them appropriately.
#
# Aditionally, the assert statement can be used to raise the Assertion Error, if a specified condition evaluates to False.

# %%
x = 10 

if x > 5 : 
    raise ValueError("x should not be greater than 5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 x = 10
#       3 if x > 5 :
# ----> 4     raise ValueError("x should not be greater than 5")
#
# ValueError: x should not be greater than 5

# %% [markdown]
# Q6.
# What are the various file access modes available in Python's open() function, and how do they affect file
# handling

# %% [markdown]
# Ans.
# The purpose of the try.except block in Python to handle exceptions gracefully and prevent them from terminating the program
# abruptly.
#
# The try block contains the code that may raise an exception while  the except block contains the code to handle the exception
# while the except block contains the code to ahndle the exception if it occurs.
#
# By try._except blocks, developers can anticipate and respond to potential errors, ensuring the robustness and reliability of programs.

# %% [markdown]
# Q7.
# Explain the process of catching exceptions using the `try...except` block in Python. Illustrate with
# examples

# %% [markdown]
# The process of catching the exceptions using the try....except bllock in Python is as :
# catching exceptions using the try....except block involves placing the code that may raise an exception inside the try...except block.
#
# If an exception occurs in the try block, the interpreter searches for a matching except block. if a match is found, the code inside the corresponding except block is executed to handle the exception. If no matchingexcept block is found, the exception propogates
# up the call stack until it is caught out of the program terminates.

# %%
try : 
    result = 10/0 

except ZeroDivisionError: 
    print("Division by zero is not possible")
# Out:
# Division by zero is not possible

# %% [markdown]
# Q8.
# Discuss the use of the `finally` clause in Python exception handling. When and why is it used? Provide
# examples to support your explanation#

# %% [markdown]
# Ans.
#  The 'finalyy'clause in the Python language exception handling is used to define clean up actions, that must be executed
#  regardless of the whether an exception occurs or not.  It is typically used to release the external resources such as files or network connections or to perform the cleanup tasks like cleaning the databases connections
#
#  The finally  block is executed even if an exception is raised in the block or if the program exits the try block  through a return statement.

# %%
try: 
  file = open("example.txt", 'r') 

except FileNotFoundError :
  print("File not found")

finally: 
  file.close()
# Out:
# File not found
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5   print("File not found")
#       7 finally:
# ----> 8   file.close()
#
# NameError: name 'file' is not defined

# %% [markdown]
# Q9.
# How can multiple exceptions be handled in Python using the `try...except` block? Provide examples
# demonstrating the handling of multiple exceptions#

# %% [markdown]
# Ans.
# Multiple exceptions can be handled in Python using the try_except block by providin the multiple except blocks each ahndling the
# specific type of execution.  The except blocks are evaluated sequentially and the first block that matches the raised exception type is  executed.

# %%
try: 
    result = 10/0 

except ZeroDivisionError: 
    print("Division by Zero")

except ValueError : 
    print("Valid Error")
# Out:
# Division by Zero

# %% [markdown]
# Q10.
# What is the significance of the `else` clause in Python exception handling? How does it complement the
# `try...except` block? Provide examples to elucidate its usage#

# %% [markdown]
# Ans.
# The else  clause in Python exception handling is executed if no exception occurs in the try block. It provides a way to specify the code
# that should run oly when no exceptions are raised. The else clause complements the try...except block by seperating the code that may raise the exceptions form the code that should execute only in the code only in absence of exceptions.

# %%
try : 
    result = 10/2 
except ZeroDivisionError : 
    print("Division by Zero")
else: 
    print("Division Successful")
# Out:
# Division Successful

# %% [markdown]
# Q11.  What is operator overloading in Python, and how does it allow for customization of built-in operators5

# %% [markdown]
# Ans.
# Operator Overloading in Python allows the custom classes to define their own behaviour for built in operators such as +,-, *, /.
# It enable the developers to extend the functionality f operators to work with custom objects y defining special methods within the class.

# %% [markdown]
# Q12. Explain the significance of magic methods (or dunder methods) in Python operator overloading. Provide
# examples of commonly used magic methods for operator overloading# ?

# %% [markdown]
# Ans.
# Magic Methods also known as the dunder methods play a crucial role in operator overloading in Python. These methods are invoked implicitly by the interpreter toimplement the specific behaviour of the built in operators when used with custom objects.
#
# Examples of commonly used magic methods for the operators overloading include : __add__, __sub__, , __mul__, __div__

# %% [markdown]
# Q13.
# Describe the process of implementing operator overloading in a custom Python class. Provide an
# example demonstrating the overloading of addition and subtraction operators#

# %% [markdown]
# Ans.
# Implementing operator overloading in a custom Python class involves the defining of the specai methods within the class to handle the specific opeators . For example, to overload the addition and subtraction operators, you woulld define the __add__ and __sub__ methods respectively.

# %%
# an example of the code is: 
class Vector : 
    def __init__(self, x,y): 
        self.x = x 
        self.y = y 

    def __add__(self, other): 
        if isinstance(other,Vector): 
            return Vector(self.x + other.x, self.y + other.y)
        else: 
            raise TypeError ("Unsupported operand type for addition")
        
    def __sub__(self, other): 
        if isinstance(other,Vector): 
            return Vector (self.x - other.x, self.y - other.y)
        
        else : 
            raise TypeError("Unsupported operand type for subtraction")

    def __repr__(self): 
        return f"Vector ({self.x}, {self.y})" 
    
v1 = Vector(1,2)
v2 = Vector(3,4) 

result_add = v1 = v2 
result_sub = v1 - v2 

print(result_add)
print(result_sub)
# Out:
# Vector (3, 4)
# Vector (0, 0)

# %% [markdown]
# Q14.
# How do comparison operators and assignment operators contribute to operator overloading in Python?
# Provide examples illustrating their usage in custom class implementations#

# %% [markdown]
# Ans .
# Comparison Operators and assignment operators contribute to the operator overloading in Python by allowing the custom classes to define behaviour for equality , comparison, and in-place modification operations.
#
# These operators enable developers to make custom objects work seamlessly with Python's built in operators.

# %% [markdown]
# Q15.
# Discuss the advantages of operator overloading in Python programming. How does it improve code
# readability, expressiveness, and maintainability?

# %% [markdown]
# Ans.
# Operator overloading in Python offers several advantages including the improved code readibility by allowing the intutive actions on custom objects, incresed expensiveness by incorporating the mathematical and logicaal operations directly into class definitions and and enhanced maintainibility by proovidinga clear and concise ay to define the custom behaviour for operators.
#
# Additionally, operator overloading facilitates the development
# of domain-specific languages and promotes code reuse through the use of familiar syntax and semantics.
